# %% [markdown]
# # 🐍 Bem-vindo ao JupyterLite!
#
# Este notebook roda **inteiramente no seu navegador** usando Pyodide (Python compilado para WebAssembly).
#
# Você pode editar as células, executar código e salvar — tudo localmente no seu navegador.

# %%
# Clique nesta célula e pressione Shift+Enter para executar
print("Olá! O Python está rodando no seu navegador! 🎉")

# %%
# Exemplo: operações matemáticas
import math

raio = 5
area = math.pi * raio ** 2
print(f"Área de um círculo com raio {raio}: {area:.2f}")

# %%
# Exemplo: listas e loops
frutas = ["🍎 Maçã", "🍌 Banana", "🍊 Laranja", "🍇 Uva"]

for i, fruta in enumerate(frutas, 1):
    print(f"{i}. {fruta}")
